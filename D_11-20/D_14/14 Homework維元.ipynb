# %% [markdown]
# # [作業目標]
#
#
# 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？
#
# 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %% [markdown]
# # 作業

# %%
# 記得先 Import 正確的套件

import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv')
df1
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df2 = pd.read_csv(
    'https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv',
    keep_default_na=True,
    na_values=['na', '--']
)
df2
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %% [markdown]
# #### 會對預設的 NaN 值做判斷，但 na、-- 不在預設的範圍內所以沒有被轉換。

# %% [markdown]
# ### 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums')
response = r.text

import json
data = json.loads(response)

# print(data)

# %%
df = pd.DataFrame(data)
df = df.sort_values(by = 'subscriptionCount', ascending = False)
df.to_csv('Dcard.csv')

# %%
pd.read_csv('Dcard.csv')
# Out:
#      Unnamed: 0                                    id                 alias  \
# 0           373  1ce3ebca-8701-42d5-b14c-076fc629bc8e                   sex
# 1           228  42851318-b9e2-4a75-8a05-9fe180becefe          relationship
# 2           224  be1a095b-175e-4523-9e06-66a05d939676               dressup
# 3           217  cbd5285f-3cba-4bfc-86d0-1ab52d201459                makeup
# 4           233  06e07db4-c8b5-4dae-851f-e8a8236e770c                  meme
# ..          ...                                   ...                   ...
# 520         209  36443e19-9334-42f4-b91e-95e601150f61                 hkacg
# 521         172  9e2ea80f-3342-4533-bb7a-d639e6c517e7               athlete
# 522         207  019f0994-375e-479a-9b08-1b8addb64cc3              hkbeauty
# 523         521  a932e2a7-be88-4c56-9ae9-ef4eb009666f  advancedPermission02
# 524         208  1150ae79-6e67-46f2-bfec-74f8c365a4a1            hktrending
#
#                  name                                        description  \
# 0                  西斯  西斯板（Sex）提供男女私密話題分享或性教育等情慾議題討論，若有性方面相關問題也可在此發問。...
# 1                  感情  無論是遠距離戀愛、情侶間的有趣互動、分手後的藕斷絲連等...都可以在感情板分享你們的愛情故事...
# 2                  穿搭  穿搭板提供各種服裝搭配、包鞋、飾品配件等相關話題討論。\n歡迎分享自己的日常穿搭，或任何潮流...
# 3                  美妝  不管你喜歡開架彩妝還是專櫃彩妝，美妝板提供各種最新彩妝開箱評比、粉底色號、唇膏試色、眼影試色...
# 4                  梗圖                                            梗圖=有梗的圖
# ..                ...                                                ...
# 520            港澳 ACG           呢度係比香港澳門既同學仔討論同分享各種動漫、遊戲嘅討論區，發文留言前請先閱讀板規
# 521                選手                                                NaN
# 522         港澳 Beauty    呢度係比香港澳門嘅同學仔討論化妝、護膚、美髮、任何扮靚相關話題嘅討論區，發文留言前請先閱讀板規
# 523  正在測試中的進階權限測試看板02  做為日本最具代表性的藝術風格，浮世繪之美始終讓人深深著迷，不管是19世紀印象派大師，抑或是當...
# 524              港澳時事           呢度係比香港澳門嘅同學仔討論同港澳有關既時事議題嘅討論區，發文留言前請先閱讀板規
#
#      subscriptionCount  subscribed   read                 createdAt  \
# 0               628779       False  False  2020-02-04T07:52:53.573Z
# 1               572172       False  False  2020-02-04T07:28:43.573Z
# 2               562942       False  False  2020-02-04T07:28:03.573Z
# 3               471887       False  False  2020-02-04T07:26:53.573Z
# 4               453768       False  False  2020-02-04T07:29:33.573Z
# ..                 ...         ...    ...                       ...
# 520                  1       False  False  2020-01-02T03:23:17.450Z
# 521                  0       False  False  2017-08-22T05:22:03.772Z
# 522                  0       False  False  2020-01-02T03:21:28.406Z
# 523                  0       False  False  2021-08-18T08:43:00.111Z
# 524                  0       False  False  2020-01-02T03:22:36.962Z
#
#                     updatedAt  ...   nsfw  \
# 0    2021-06-24T04:50:12.522Z  ...   True
# 1    2021-04-20T08:36:40.391Z  ...  False
# 2    2021-08-14T10:19:26.675Z  ...  False
# 3    2021-06-25T07:07:20.485Z  ...  False
# 4    2020-08-31T09:47:51.769Z  ...  False
# ..                        ...  ...    ...
# 520  2021-07-23T11:09:33.256Z  ...  False
# 521  2020-08-13T06:02:20.625Z  ...  False
# 522  2021-07-23T11:09:49.210Z  ...  False
# 523  2021-08-20T06:11:35.367Z  ...  False
# 524  2021-07-23T11:07:17.530Z  ...  False
#
#                              mediaThreshold  limitCountries  limitStage  \
# 0    {'RACY': 1, 'ADULT': 1, 'VIOLENCE': 1}              []           0
# 1                                        {}              []           0
# 2                                        {}              []           0
# 3                                        {}              []           0
# 4                                        {}              []           0
# ..                                      ...             ...         ...
# 520                                      {}    ['HK', 'MO']           0
# 521                                      {}              []           0
# 522                                      {}    ['HK', 'MO']           0
# 523                                      {}              []           0
# 524                                      {}    ['HK', 'MO']           0
#
#                           availableLayouts              postCount favorite  \
# 0                              ['classic']   {'last30Days': 5409}    False
# 1                              ['classic']  {'last30Days': 10697}    False
# 2                      ['classic', 'link']   {'last30Days': 1627}    False
# 3                              ['classic']   {'last30Days': 3378}    False
# 4                                ['image']   {'last30Days': 2381}    False
# ..                                     ...                    ...      ...
# 520  ['classic', 'image', 'video', 'link']     {'last30Days': 27}    False
# 521                    ['classic', 'link']      {'last30Days': 1}    False
# 522  ['classic', 'image', 'video', 'link']     {'last30Days': 46}    False
# 523  ['classic', 'image', 'video', 'link']      {'last30Days': 1}    False
# 524  ['classic', 'image', 'video', 'link']     {'last30Days': 81}    False
#
#      enablePrivateMessage                                          heroImage  \
# 0                   False  {'url': 'https://megapx-assets.dcard.tw/images...
# 1                   False  {'url': 'https://megapx-assets.dcard.tw/images...
# 2                    True  {'url': 'https://megapx-assets.dcard.tw/images...
# 3                   False  {'url': 'https://megapx-assets.dcard.tw/images...
# 4                   False  {'url': 'https://megapx-assets.dcard.tw/images...
# ..                    ...                                                ...
# 520                  True  {'url': 'https://megapx-assets.dcard.tw/images...
# 521                 False                                                NaN
# 522                 False  {'url': 'https://megapx-assets.dcard.tw/images...
# 523                 False                                                NaN
# 524                 False  {'url': 'https://megapx-assets.dcard.tw/images...
#
#                                                   logo
# 0    {'url': 'https://megapx-assets.dcard.tw/images...
# 1    {'url': 'https://megapx-assets.dcard.tw/images...
# 2    {'url': 'https://megapx-assets.dcard.tw/images...
# 3    {'url': 'https://megapx-assets.dcard.tw/images...
# 4    {'url': 'https://megapx-assets.dcard.tw/images...
# ..                                                 ...
# 520  {'url': 'https://megapx-assets.dcard.tw/images...
# 521                                                NaN
# 522  {'url': 'https://megapx-assets.dcard.tw/images...
# 523                                                NaN
# 524  {'url': 'https://megapx-assets.dcard.tw/images...
#
# [525 rows x 35 columns]
